# %%
import pandas as pd
df = pd.read_csv('housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# get only the first 100 rows

small_df = df[:500]

# Streudiagramm mit unterschiedlichen Größen der Datenpunkte
plt.figure(figsize=(10, 6))
scatter = plt.scatter(small_df['median_house_value'], small_df['total_bedrooms'], s=small_df['median_income']*10, c='blue', alpha=0.2, edgecolors='w', linewidth=0.5)

# Titel und Achsenbeschriftungen
plt.title('Streudiagramm mit Größenunterschieden', fontsize=15)
plt.xlabel('Median House Value [USD]', fontsize=12)
plt.ylabel('Total Bedrooms', fontsize=12)

# Legende erstellen
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend1 = plt.legend(handles, labels, title="Median Income [USD]*10", loc="upper right")

# Diagramm anzeigen
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# get only the first 100 rows

small_df = df[:500]

# Streudiagramm mit unterschiedlichen Größen der Datenpunkte
plt.figure(figsize=(10, 6))
scatter = plt.scatter(small_df['median_house_value'], small_df['total_bedrooms'], c=small_df['median_income'], cmap='jet', alpha=0.2, edgecolors='w', linewidth=0.5)

# Titel und Achsenbeschriftungen
plt.title('Streudiagramm mit Colormap jet', fontsize=15)
plt.xlabel('Median House Value [USD]', fontsize=12)
plt.ylabel('Total Bedrooms', fontsize=12)
plt.colorbar()

# Diagramm anzeigen
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# get only the first 100 rows

small_df = df[:500]

# Streudiagramm mit unterschiedlichen Größen der Datenpunkte
plt.figure(figsize=(10, 6))
scatter = plt.scatter(small_df['median_house_value'], small_df['total_bedrooms'], c=small_df['median_income'], cmap='viridis', alpha=0.2, edgecolors='w', linewidth=0.5)

# Titel und Achsenbeschriftungen
plt.title('Streudiagramm mit Colormap viridis', fontsize=15)
plt.xlabel('Median House Value [USD]', fontsize=12)
plt.ylabel('Total Bedrooms', fontsize=12)
plt.colorbar()

# Diagramm anzeigen
plt.grid(True)
plt.savefig('viridis_scatterplot.png')
plt.show()

# %%
import cv2 as cv

img = cv.imread('viridis_scatterplot.png')
#convert to black and white
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#show image
plt.figure(figsize=(15, 9))
plt.imshow(gray, cmap='gray')
# make bigger
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# get only the first 100 rows

small_df = df[0:750]

markers = {'NEAR BAY': 'o', '<1H OCEAN': 's', 'INLAND': '^'}
small_df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
for cls in small_df['ocean_proximity'].unique():
    subset = small_df[small_df['ocean_proximity'] == cls]
    plt.scatter(small_df['median_house_value'], small_df['total_bedrooms'], label=f'Class {cls}', marker=markers[cls], alpha=0.8, edgecolors='w', linewidth=0.5)

# Streudiagramm mit unterschiedlichen Größen der Datenpunkte
#scatter = plt.scatter(small_df['median_house_value'], small_df['total_bedrooms'], marker=small_df['ocean_proximity'], cmap='viridis', alpha=0.2, edgecolors='w', linewidth=0.5)

# Titel und Achsenbeschriftungen
plt.title('Streudiagramm mit Colormap viridis', fontsize=15)
plt.xlabel('Median House Value [USD]', fontsize=12)
plt.ylabel('Total Bedrooms', fontsize=12)
plt.legend()

# Diagramm anzeigen
plt.grid(True)
plt.savefig('viridis_scatterplot.png')
plt.show()

# %%
# Make plot with different shapes. Use random datapoints.
import matplotlib.pyplot as plt
import numpy as np

# get 500 random rows

small_df = df.sample(n=500, random_state=0)

markers = {'NEAR BAY': 'o', '<1H OCEAN': 's', 'INLAND': '^', 'NEAR OCEAN': 'D', 'ISLAND': 'P'}
small_df['ocean_proximity'].unique()

plt.figure(figsize=(10, 6))
for cls in small_df['ocean_proximity'].unique():
    subset = small_df[small_df['ocean_proximity'] == cls]
    plt.scatter(subset['median_house_value'], subset['total_bedrooms'], label=f'Class {cls}', marker=markers[cls], alpha=0.8, edgecolors='w', linewidth=0.5)
    
# Titel und Achsenbeschriftungen
plt.title('Streudiagramm mit unterschiedlichen Formen', fontsize=15)
plt.xlabel('Median House Value [USD]', fontsize=12)
plt.ylabel('Total Bedrooms', fontsize=12)
plt.legend()

# Diagramm anzeigen
plt.grid(True)
plt.show()
